# %% [markdown]
# # Task 1.1 [y] - Next value prediction

# %% [markdown]
# > Luca Laboccetta,
# > Giorgio Andronico

# %% [markdown]
# ## Data understanding

# %% [markdown]
# ### Initial data collection

# %% [markdown]
# Boilerplate code: importing useful modules, choosing compute backend, mounting Google Drive

# %%
import keras
import pandas as pd
from sklearn.metrics import mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils.vis_utils import plot_model
from google.colab import drive
import tensorflow as tf
# !pip install -q -U keras-tuner
import keras_tuner as kt

# Choose computing backend
computing_resource = tf.test.gpu_device_name()
if "GPU" not in computing_resource:
  computing_resource = "/CPU:0"
print(f"Computing resource: {computing_resource}")

# Mount Google Drive
drive.mount('/content/drive')

# Setting seed for reproducibility
seed = 44
np.random.seed(seed)
tf.random.set_seed(seed)
# Out:
#      |████████████████████████████████| 135 kB 5.8 MB/s
#      |████████████████████████████████| 1.6 MB 43.6 MB/s
# Computing resource: /device:GPU:0
# Mounted at /content/drive

# %% [markdown]
# Load *Healthware* dataset, both train and test. Loading *y* column only, as this notebook focuses only on analyzing this column

# %%
train = pd.read_csv("/content/drive/MyDrive/DeepLearning/Datasets/Progetto/train.csv").drop('x', 1).drop('z', 1)
test_set = pd.read_csv("/content/drive/MyDrive/DeepLearning/Datasets/Progetto/test.csv").drop('x', 1).drop('z', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %% [markdown]
# ### Data exploration

# %% [markdown]
# Datasets' shapes

# %%
print("Train dataset shape:")
print(train.shape)
print("Test dataset shape:")
print(test_set.shape)
# Out:
# Train dataset shape:
# (144911, 1)
# Test dataset shape:
# (148371, 1)

# %% [markdown]
# Statistical quantities for each column

# %%
train.describe()
# Out:
#                    y
# count  144911.000000
# mean      -34.800146
# std       594.977813
# min     -1019.000000
# 25%      -646.000000
# 50%       -14.000000
# 75%       466.000000
# max      1078.000000

# %% [markdown]
# Object types (this is useful to see how *pandas* parsed the .csv file)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144911 entries, 0 to 144910
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   y       144911 non-null  int64
# dtypes: int64(1)
# memory usage: 1.1 MB

# %% [markdown]
# #### Data visualization

# %% [markdown]
# The y-axis depicts the value of the single instance, while the x-axis is merely the row index of that instance.

# %%
fig = plt.figure(figsize=(20, 8))
plt.plot(train)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# #### Normalization and splitting

# %% [markdown]
# Normalizing train data in a -1:1 range

# %%
mean = train.mean()
std = train.std()
train = (train - mean) / std
train
# Out:
#                y
# 0       1.317360
# 1       1.621573
# 2       1.340891
# 3       0.799694
# 4       1.243408
# ...          ...
# 144906 -1.291140
# 144907 -1.291140
# 144908 -1.289460
# 144909 -1.291140
# 144910 -1.289460
#
# [144911 rows x 1 columns]

# %% [markdown]
# Normalizing test data in a -1:1 range

# %%
mean = test_set.mean()
std = test_set.std()
test_set = (test_set - mean) / std
test_set
# Out:
#                y
# 0      -1.976507
# 1      -1.972326
# 2      -1.993233
# 3      -2.097768
# 4      -2.116584
# ...          ...
# 148366 -0.427297
# 148367 -0.427297
# 148368 -0.427297
# 148369 -0.427297
# 148370 -0.427297
#
# [148371 rows x 1 columns]

# %% [markdown]
# Creation of the validation set, extracting 30% of the training set

# %%
n_rows_train = round(len(train)*0.7)
train_set = train[:n_rows_train]
validation_set = train[n_rows_train:]
validation_set.index = np.arange(0, len(validation_set))
validation_set
# Out:
#               y
# 0     -1.573504
# 1     -1.570142
# 2     -1.563419
# 3     -1.430641
# 4     -1.575185
# ...         ...
# 43468 -1.291140
# 43469 -1.291140
# 43470 -1.289460
# 43471 -1.291140
# 43472 -1.289460
#
# [43473 rows x 1 columns]

# %% [markdown]
# #### Labeling the dataset

# %% [markdown]
# Defining the windowing function

# %%
def generate_windows(df, window_size, window_shift):
    windows = []
    labels = []

    for i in range(0, len(df), window_shift):
        if (i + window_size >= len(df)):
            break

        windows.append(df[i: i + window_size])
        labels.append(df.iloc[i + window_size])
    
    return np.array(windows, dtype=np.float32), np.array(labels, dtype=np.float32)

# %% [markdown]
# Windowing the dataset

# %%
window_size = 30
window_shift = 6

X_train, y_train = generate_windows(train_set, window_size, window_shift)
X_val, y_val = generate_windows(validation_set, window_size, window_shift)
X_test, y_test = generate_windows(test_set, window_size, window_shift)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Hyperparameter search

# %% [markdown]
# Defining model skeleton and search ranges for each hyperparameter

# %%
def build_model(hp):
  model = Sequential()
  LSTM_1_units = hp.Int('LSTM_1_units', min_value=16, max_value=128, step=16)
  dropout_rate = 0.1

  # return_sequences=True needed to chain second LSTM!
  model.add(LSTM(LSTM_1_units,
                 input_shape=(window_size, X_train.shape[2])))
  model.add(Dense(1))

  lr_choices = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_choices), loss='mae')
  return model

# %% [markdown]
# Instantiating of the tuner on the model skeleton defined above. Definition of early stopping criteria.

# %%
tuner = kt.Hyperband(build_model, objective='val_loss', max_epochs=50, seed=seed)
# If val_loss does not improve in five epochs straight, stop training
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# Searching for the best hyperparameters

# %%
with tf.device(computing_resource):
    tuner.search(np.array(X_train), 
                np.array(y_train), 
                validation_data=(X_val, y_val), 
                callbacks=[early_stop])
# Out:
# Trial 24 Complete [00h 00m 08s]
# val_loss: 0.08599589020013809
#
# Best val_loss So Far: 0.07900131493806839
# Total elapsed time: 00h 04m 22s

# %% [markdown]
# Printing the best parameters found

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. 
The optimal number of units in the first LSTM is {best_hps.get('LSTM_1_units')}.
The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete.
# The optimal number of units in the first LSTM is 80.
# The optimal learning rate for the optimizer is 0.001.

# %% [markdown]
# ### Fitting and building

# %% [markdown]
# Building the model with the best hyperparameters found above

# %%
model = tuner.hypermodel.build(best_hps)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Compiling and training the model on these parameters

# %%
model.compile(loss='mae', 
              optimizer=tf.keras.optimizers.Adam(
                  learning_rate=best_hps.get('learning_rate')))
with tf.device(computing_resource):
    history = model.fit(X_train,
                        y_train, 
                        epochs=150, 
                        validation_data=(X_val, y_val))
# Out:
# Epoch 1/150
# 529/529 [==============================] - 5s 6ms/step - loss: 0.1440 - val_loss: 0.0869
# Epoch 2/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.1003 - val_loss: 0.0790
# Epoch 3/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0830
# Epoch 4/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0786
# Epoch 5/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0850
# Epoch 6/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0933 - val_loss: 0.0874
# Epoch 7/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0928 - val_loss: 0.0812
# Epoch 8/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0928 - val_loss: 0.0809
# Epoch 9/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0927 - val_loss: 0.0787
# Epoch 10/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0926 - val_loss: 0.0792
# Epoch 11/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0924 - val_loss: 0.0819
# Epoch 12/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0781
# Epoch 13/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0924 - val_loss: 0.0777
# Epoch 14/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0925 - val_loss: 0.0780
# Epoch 15/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0921 - val_loss: 0.0781
# Epoch 16/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0922 - val_loss: 0.0790
# Epoch 17/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0792
# Epoch 18/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0921 - val_loss: 0.0788
# Epoch 19/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0791
# Epoch 20/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0922 - val_loss: 0.0798
# Epoch 21/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0920 - val_loss: 0.0781
# Epoch 22/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0919 - val_loss: 0.0817
# Epoch 23/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0919 - val_loss: 0.0778
# Epoch 24/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0919 - val_loss: 0.0808
# Epoch 25/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0785
# Epoch 26/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0918 - val_loss: 0.0777
# Epoch 27/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0916 - val_loss: 0.0780
# Epoch 28/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0918 - val_loss: 0.0785
# Epoch 29/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0918 - val_loss: 0.0773
# Epoch 30/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0918 - val_loss: 0.0791
# Epoch 31/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0916 - val_loss: 0.0776
# Epoch 32/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0784
# Epoch 33/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0916 - val_loss: 0.0783
# Epoch 34/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0783
# Epoch 35/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0777
# Epoch 36/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0916 - val_loss: 0.0791
# Epoch 37/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0778
# Epoch 38/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0781
# Epoch 39/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0913 - val_loss: 0.0794
# Epoch 40/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0799
# Epoch 41/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0783
# Epoch 42/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0913 - val_loss: 0.0797
# Epoch 43/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0912 - val_loss: 0.0779
# Epoch 44/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0911 - val_loss: 0.0781
# Epoch 45/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0911 - val_loss: 0.0778
# Epoch 46/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0913 - val_loss: 0.0778
# Epoch 47/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0912 - val_loss: 0.0780
# Epoch 48/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0911 - val_loss: 0.0789
# Epoch 49/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0912 - val_loss: 0.0790
# Epoch 50/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0911 - val_loss: 0.0804
# Epoch 51/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0909 - val_loss: 0.0781
# Epoch 52/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0908 - val_loss: 0.0781
# Epoch 53/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0910 - val_loss: 0.0772
# Epoch 54/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0912 - val_loss: 0.0778
# Epoch 55/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0908 - val_loss: 0.0776
# Epoch 56/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0909 - val_loss: 0.0794
# Epoch 57/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0907 - val_loss: 0.0782
# Epoch 58/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0778
# Epoch 59/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0905 - val_loss: 0.0787
# Epoch 60/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0777
# Epoch 61/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0780
# Epoch 62/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0905 - val_loss: 0.0778
# Epoch 63/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0903 - val_loss: 0.0783
# Epoch 64/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0901 - val_loss: 0.0783
# Epoch 65/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0903 - val_loss: 0.0793
# Epoch 66/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0903 - val_loss: 0.0785
# Epoch 67/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0901 - val_loss: 0.0784
# Epoch 68/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0900 - val_loss: 0.0797
# Epoch 69/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0900 - val_loss: 0.0778
# Epoch 70/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0898 - val_loss: 0.0791
# Epoch 71/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0897 - val_loss: 0.0791
# Epoch 72/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0898 - val_loss: 0.0788
# Epoch 73/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0896 - val_loss: 0.0778
# Epoch 74/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0893 - val_loss: 0.0781
# Epoch 75/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0896 - val_loss: 0.0778
# Epoch 76/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0893 - val_loss: 0.0827
# Epoch 77/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0890 - val_loss: 0.0781
# Epoch 78/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0890 - val_loss: 0.0778
# Epoch 79/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0888 - val_loss: 0.0784
# Epoch 80/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0886 - val_loss: 0.0795
# Epoch 81/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0889 - val_loss: 0.0787
# Epoch 82/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0885 - val_loss: 0.0797
# Epoch 83/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0884 - val_loss: 0.0786
# Epoch 84/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0884 - val_loss: 0.0801
# Epoch 85/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0882 - val_loss: 0.0785
# Epoch 86/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0878 - val_loss: 0.0788
# Epoch 87/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0881 - val_loss: 0.0781
# Epoch 88/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0876 - val_loss: 0.0799
# Epoch 89/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0875 - val_loss: 0.0781
# Epoch 90/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0873 - val_loss: 0.0787
# Epoch 91/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0873 - val_loss: 0.0790
# Epoch 92/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0871 - val_loss: 0.0793
# Epoch 93/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0872 - val_loss: 0.0800
# Epoch 94/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0868 - val_loss: 0.0806
# Epoch 95/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0867 - val_loss: 0.0808
# Epoch 96/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0863 - val_loss: 0.0792
# Epoch 97/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0863 - val_loss: 0.0794
# Epoch 98/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0859 - val_loss: 0.0797
# Epoch 99/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0860 - val_loss: 0.0808
# Epoch 100/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0858 - val_loss: 0.0807
# Epoch 101/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0856 - val_loss: 0.0802
# Epoch 102/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0856 - val_loss: 0.0808
# Epoch 103/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0850 - val_loss: 0.0795
# Epoch 104/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0852 - val_loss: 0.0819
# Epoch 105/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0850 - val_loss: 0.0792
# Epoch 106/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0844 - val_loss: 0.0795
# Epoch 107/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0845 - val_loss: 0.0804
# Epoch 108/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0840 - val_loss: 0.0808
# Epoch 109/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0840 - val_loss: 0.0794
# Epoch 110/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0835 - val_loss: 0.0808
# Epoch 111/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0838 - val_loss: 0.0813
# Epoch 112/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0834 - val_loss: 0.0819
# Epoch 113/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0831 - val_loss: 0.0809
# Epoch 114/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0830 - val_loss: 0.0804
# Epoch 115/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0828 - val_loss: 0.0812
# Epoch 116/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 117/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0822 - val_loss: 0.0821
# Epoch 118/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0820 - val_loss: 0.0805
# Epoch 119/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0820 - val_loss: 0.0826
# Epoch 120/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0813 - val_loss: 0.0815
# Epoch 121/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0811 - val_loss: 0.0820
# Epoch 122/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0811 - val_loss: 0.0822
# Epoch 123/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0805 - val_loss: 0.0823
# Epoch 124/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0800 - val_loss: 0.0820
# Epoch 125/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0801 - val_loss: 0.0820
# Epoch 126/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0799 - val_loss: 0.0825
# Epoch 127/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0798 - val_loss: 0.0842
# Epoch 128/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0793 - val_loss: 0.0840
# Epoch 129/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0789 - val_loss: 0.0823
# Epoch 130/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0790 - val_loss: 0.0845
# Epoch 131/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0787 - val_loss: 0.0830
# Epoch 132/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0785 - val_loss: 0.0832
# Epoch 133/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0785 - val_loss: 0.0819
# Epoch 134/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0782 - val_loss: 0.0844
# Epoch 135/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0777 - val_loss: 0.0834
# Epoch 136/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0776 - val_loss: 0.0826
# Epoch 137/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0770 - val_loss: 0.0835
# Epoch 138/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0766 - val_loss: 0.0848
# Epoch 139/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0765 - val_loss: 0.0832
# Epoch 140/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0764 - val_loss: 0.0832
# Epoch 141/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0762 - val_loss: 0.0831
# Epoch 142/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0757 - val_loss: 0.0864
# Epoch 143/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0759 - val_loss: 0.0847
# Epoch 144/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0752 - val_loss: 0.0835
# Epoch 145/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0751 - val_loss: 0.0838
# Epoch 146/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0749 - val_loss: 0.0859
# Epoch 147/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0747 - val_loss: 0.0836
# Epoch 148/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0742 - val_loss: 0.0858
# Epoch 149/150
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0743 - val_loss: 0.0837
# Epoch 150/150
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0739 - val_loss: 0.0834

# %% [markdown]
# Taking the epoch where metrics have been best and re-training the model only for that number of epochs

# %%
val_loss_per_epoch = history.history['val_loss']
best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
print(f'Epoch with lowest validation loss: {best_epoch}')

hypermodel_best_epoch = tuner.hypermodel.build(best_hps)
with tf.device(computing_resource):
    history = hypermodel_best_epoch.fit(X_train, 
                                        y_train, 
                                        epochs=best_epoch, 
                                        validation_data=(X_val, y_val))
# Out:
# Epoch with lowest validation loss: 53
# Epoch 1/53
# 529/529 [==============================] - 5s 6ms/step - loss: 0.1478 - val_loss: 0.0952
# Epoch 2/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.1011 - val_loss: 0.0796
# Epoch 3/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0779
# Epoch 4/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0792
# Epoch 5/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0935 - val_loss: 0.0802
# Epoch 6/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0830
# Epoch 7/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0932 - val_loss: 0.0789
# Epoch 8/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0927 - val_loss: 0.0800
# Epoch 9/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0928 - val_loss: 0.0789
# Epoch 10/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0928 - val_loss: 0.0803
# Epoch 11/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0800
# Epoch 12/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0925 - val_loss: 0.0786
# Epoch 13/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0789
# Epoch 14/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0926 - val_loss: 0.0777
# Epoch 15/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0921 - val_loss: 0.0787
# Epoch 16/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0923 - val_loss: 0.0788
# Epoch 17/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0919 - val_loss: 0.0805
# Epoch 18/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0923 - val_loss: 0.0799
# Epoch 19/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0924 - val_loss: 0.0801
# Epoch 20/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0920 - val_loss: 0.0803
# Epoch 21/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0919 - val_loss: 0.0787
# Epoch 22/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0782
# Epoch 23/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0920 - val_loss: 0.0803
# Epoch 24/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0921 - val_loss: 0.0783
# Epoch 25/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0773
# Epoch 26/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0784
# Epoch 27/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0918 - val_loss: 0.0775
# Epoch 28/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0918 - val_loss: 0.0793
# Epoch 29/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0778
# Epoch 30/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0779
# Epoch 31/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0914 - val_loss: 0.0777
# Epoch 32/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0917 - val_loss: 0.0776
# Epoch 33/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0915 - val_loss: 0.0782
# Epoch 34/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0913 - val_loss: 0.0784
# Epoch 35/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0779
# Epoch 36/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0915 - val_loss: 0.0794
# Epoch 37/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0914 - val_loss: 0.0791
# Epoch 38/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0914 - val_loss: 0.0778
# Epoch 39/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0910 - val_loss: 0.0778
# Epoch 40/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0914 - val_loss: 0.0790
# Epoch 41/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0912 - val_loss: 0.0773
# Epoch 42/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0914 - val_loss: 0.0774
# Epoch 43/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0911 - val_loss: 0.0789
# Epoch 44/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0911 - val_loss: 0.0800
# Epoch 45/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0910 - val_loss: 0.0782
# Epoch 46/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0911 - val_loss: 0.0808
# Epoch 47/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0910 - val_loss: 0.0793
# Epoch 48/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0909 - val_loss: 0.0783
# Epoch 49/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0909 - val_loss: 0.0778
# Epoch 50/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0910 - val_loss: 0.0783
# Epoch 51/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0907 - val_loss: 0.0777
# Epoch 52/53
# 529/529 [==============================] - 3s 5ms/step - loss: 0.0908 - val_loss: 0.0775
# Epoch 53/53
# 529/529 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0775

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Metrics

# %% [markdown]
# The plot shows a gradual decrease in both training and validation loss, with validation steadily staying below training. No sign of overfitting. The x-axis depicts the epoch, while the y-axis depicts the loss value for that epoch.

# %%
loss = history.history['loss'] 
val_loss = history.history['val_loss'] 
epochs = range(len(loss))
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Predictions

# %% [markdown]
# Creating predictions from the test set

# %%
pred_test = hypermodel_best_epoch.predict(X_test)
# Out:
# 773/773 [==============================] - 2s 2ms/step

# %% [markdown]
# Evaluating accuracy of the predictions

# %%
denormalized_predictions = (pred_test * std['y']) + mean['y']
denormalized_original_values = (y_test * std['y']) + mean['y']
mae_test = mean_absolute_error(denormalized_original_values, denormalized_predictions)
print(f'MAE for variable Y: {mae_test}')
# Out:
# MAE for variable Y: 80.2264404296875
